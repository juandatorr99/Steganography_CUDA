# %% [markdown]
# Importing the Drive to the environment

# %%
from google.colab import drive
drive.mount('/content/drive') 

# %cd "/content/drive/My Drive/PLProject/Steganography_CUDA"
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/PLProject/Steganography_CUDA
# Environment.ipynb  hide.out   one.txt	  pikaoutput.png  README.md  show.out
# hide.cu		   input.png  output.png  pika.png	  show.cu

# %% [markdown]
# Get directory
#
#
# ```
# cd drive/MyDrive/PLProject/Steganography_CUDA
# ```
#
#
#
# To compile hide
# ```
# nvcc hide.cu `pkg-config --cflags opencv` -o hide.out `pkg-config --libs opencv`
# ```
#
# Run
# ```
# ./hide.out input.png one.txt output.png
# ```
#
# To compile show
# ```
# nvcc show.cu `pkg-config --cflags opencv` -o show.out `pkg-config --libs opencv`
# ```
#
# Run show
#
#
# ```
# ./show.out output.png
# ```

# %%
from IPython.display import JSON
from google.colab import output
from subprocess import getoutput
import os

def shell(command):
  if command.startswith('cd'):
    path = command.strip().split(maxsplit=1)[1]
    os.chdir(path)
    return JSON([''])
  return JSON([getoutput(command)])
output.register_callback('shell', shell)

# %%
#@title Colab Shell
# %%html
<div id=term_demo></div>
<script src="https://code.jquery.com/jquery-latest.js"></script>
<script src="https://cdn.jsdelivr.net/npm/jquery.terminal/js/jquery.terminal.min.js"></script>
<link href="https://cdn.jsdelivr.net/npm/jquery.terminal/css/jquery.terminal.min.css" rel="stylesheet"/>
<script>
  $('#term_demo').terminal(async function(command) {
      if (command !== '') {
          try {
              let res = await google.colab.kernel.invokeFunction('shell', [command])
              let out = res.data['application/json'][0]
              this.echo(new String(out))
          } catch(e) {
              this.error(new String(e));
          }
      } else {
          this.echo('');
      }
  }, {
      greetings: 'Welcome to Colab Shell',
      name: 'colab_demo',
      height: 250,
      prompt: 'colab > '
  });
# Out:
# <div id=term_demo></div>
# <script src="https://code.jquery.com/jquery-latest.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/jquery.terminal/js/jquery.terminal.min.js"></script>
# <link href="https://cdn.jsdelivr.net/npm/jquery.terminal/css/jquery.terminal.min.css" rel="stylesheet"/>
# <script>
#   $('#term_demo').terminal(async function(command) {
#       if (command !== '') {
#           try {
#               let res = await google.colab.kernel.invokeFunction('shell', [command])
#               let out = res.data['application/json'][0]
#               this.echo(new String(out))
#           } catch(e) {
#               this.error(new String(e));
#           }
#       } else {
#           this.echo('');
#       }
#   }, {
#       greetings: 'Welcome to Colab Shell',
#       name: 'colab_demo',
#       height: 250,
#       prompt: 'colab > '
#   });
